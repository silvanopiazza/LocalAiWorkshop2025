# %% [markdown]
# # Workshop Scope
# This notebook summarizes the workshop scope, audience, and module plan. It pairs with `docs/WORKSHOP_SCOPE.md`.

# %% [markdown]
# ## Audience
# Beginners and intermediate practitioners in biology and bioinformatics. Basic Python familiarity is assumed.

# %% [markdown]
# ## Modules
# 1. Setup & Environment
# 2. Running Local LLMs & Model Architectures
# 3. Embeddings & Semantic Search
# 4. RAG for Biology
# 5. Working with Biological Sequences
# 6. Fine-tuning / LoRA

# %%
# Cell 4: Quick system check (run in your env)
import platform, sys, shutil
print('Python:', sys.version.split()[0])
print('Platform:', platform.platform())
print('Jupyter available:', bool(shutil.which('jupyter')))
# Out:
# Python: 3.12.7
# Platform: Linux-6.12.10-76061203-generic-x86_64-with-glibc2.35
# Jupyter available: True

# %%
which python
# Out:
#   Cell In[2], line 1
#     which python
#           ^
# SyntaxError: invalid syntax
